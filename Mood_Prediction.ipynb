# %% [markdown]
#   # Predicting the mood of the person based on the song he /she is listening to
#
#   ![musicbrain.jpg](data:image/jpeg;base64,...)
#         The model will try to cluster the songs based on their features into    different groups .Then based on the song the person is listening to the model will try to classify the emotion group that song belonged to.In this way the model would be able to know the mood of the listener.

# %% [markdown]
# # New Section

# %% [markdown]
# ## Importing the necessary libraries

# %%
## For storing the data into dataframes and all
import pandas as pd
## For numerical computations
import numpy as np
## For visualising purpose
import matplotlib.pyplot as plt
# To make this notebook's output stable across runs
np.random.seed(42)
## For visualisation purpose
import seaborn as sns
import warnings

## For Speech to Text conversion
import speech_recognition as sr

# %% [markdown]
# ## Importing the dataset

# %%
songs = pd.read_csv("data.csv")

songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2017 non-null   int64
#  1   acousticness      2017 non-null   float64
#  2   danceability      2017 non-null   float64
#  3   duration_ms       2017 non-null   int64
#  4   energy            2017 non-null   float64
#  5   instrumentalness  2017 non-null   float64
#  6   key               2017 non-null   int64
#  7   liveness          2017 non-null   float64
#  8   loudness          2017 non-null   float64
#  9   mode              2017 non-null   int64
#  10  speechiness       2017 non-null   float64
#  11  tempo             2017 non-null   float64
#  12  time_signature    2017 non-null   float64
#  13  valence           2017 non-null   float64
#  14  target            2017 non-null   int64
#  15  song_title        2017 non-null   object
#  16  artist            2017 non-null   object
# dtypes: float64(10), int64(5), object(2)
# memory usage: 268.0+ KB

# %%
songs.describe()
# Out:
#         Unnamed: 0  acousticness  danceability   duration_ms       energy  \
# count  2017.000000   2017.000000   2017.000000  2.017000e+03  2017.000000
# mean   1008.000000      0.187590      0.618422  2.463062e+05     0.681577
# std     582.402066      0.259989      0.161029  8.198181e+04     0.210273
# min       0.000000      0.000003      0.122000  1.604200e+04     0.014800
# 25%     504.000000      0.009630      0.514000  2.000150e+05     0.563000
# 50%    1008.000000      0.063300      0.631000  2.292610e+05     0.715000
# 75%    1512.000000      0.265000      0.738000  2.703330e+05     0.846000
# max    2016.000000      0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2017.000000  2017.000000  2017.000000  2017.000000  2017.000000
# mean           0.133286     5.342588     0.190844    -7.085624     0.612295
# std            0.273162     3.648240     0.155453     3.761684     0.487347
# min            0.000000     0.000000     0.018800   -33.097000     0.000000
# 25%            0.000000     2.000000     0.092300    -8.394000     0.000000
# 50%            0.000076     6.000000     0.127000    -6.248000     1.000000
# 75%            0.054000     9.000000     0.247000    -4.746000     1.000000
# max            0.976000    11.000000     0.969000    -0.307000     1.000000
#
#        speechiness        tempo  time_signature      valence       target
# count  2017.000000  2017.000000     2017.000000  2017.000000  2017.000000
# mean      0.092664   121.603272        3.968270     0.496815     0.505702
# std       0.089931    26.685604        0.255853     0.247195     0.500091
# min       0.023100    47.859000        1.000000     0.034800     0.000000
# 25%       0.037500   100.189000        4.000000     0.295000     0.000000
# 50%       0.054900   121.427000        4.000000     0.492000     1.000000
# 75%       0.108000   137.849000        4.000000     0.691000     1.000000
# max       0.816000   219.331000        5.000000     0.992000     1.000000

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# examining the correlation between different features

corr_metrics=songs.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col1 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col2 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col3 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col4 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col5 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col6 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col7 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col8 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col9 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col10 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col11 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col12 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col13 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row0_col14 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col0 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col3 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col5 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col6 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col7 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col9 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col10 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col11 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col13 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row1_col14 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col0 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col1 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col3 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col4 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col5 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col6 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col8 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col9 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col10 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col11 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col12 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col13 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row2_col14 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col0 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col1 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col2 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col4 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col5 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col6 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col7 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col8 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col9 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col10 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col11 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col12 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col13 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_60e2c99c_0ed9_11eb_9c79_0071cc068248row3_col14 {
#             background-color:  #60a1ca;

# %%
# Removing the unwanted columns 

features=songs.drop(columns=["song_title","artist","Unnamed: 0"])
features.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.0102         0.833       204600   0.434          0.021900    2
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
features.describe()
# Out:
#        acousticness  danceability   duration_ms       energy  \
# count   2017.000000   2017.000000  2.017000e+03  2017.000000
# mean       0.187590      0.618422  2.463062e+05     0.681577
# std        0.259989      0.161029  8.198181e+04     0.210273
# min        0.000003      0.122000  1.604200e+04     0.014800
# 25%        0.009630      0.514000  2.000150e+05     0.563000
# 50%        0.063300      0.631000  2.292610e+05     0.715000
# 75%        0.265000      0.738000  2.703330e+05     0.846000
# max        0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2017.000000  2017.000000  2017.000000  2017.000000  2017.000000
# mean           0.133286     5.342588     0.190844    -7.085624     0.612295
# std            0.273162     3.648240     0.155453     3.761684     0.487347
# min            0.000000     0.000000     0.018800   -33.097000     0.000000
# 25%            0.000000     2.000000     0.092300    -8.394000     0.000000
# 50%            0.000076     6.000000     0.127000    -6.248000     1.000000
# 75%            0.054000     9.000000     0.247000    -4.746000     1.000000
# max            0.976000    11.000000     0.969000    -0.307000     1.000000
#
#        speechiness        tempo  time_signature      valence       target
# count  2017.000000  2017.000000     2017.000000  2017.000000  2017.000000
# mean      0.092664   121.603272        3.968270     0.496815     0.505702
# std       0.089931    26.685604        0.255853     0.247195     0.500091
# min       0.023100    47.859000        1.000000     0.034800     0.000000
# 25%       0.037500   100.189000        4.000000     0.295000     0.000000
# 50%       0.054900   121.427000        4.000000     0.492000     1.000000
# 75%       0.108000   137.849000        4.000000     0.691000     1.000000
# max       0.816000   219.331000        5.000000     0.992000     1.000000

# %% [markdown]
# # Feature Scaling

# %%
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()


loudness = features[['loudness']].values
key = features[['key']].values
tempo = features[['tempo']].values
time_signature = features[['time_signature']].values
duration_ms = features[['duration_ms']].values


features[['loudness']] = min_max_scaler.fit_transform(loudness)
features[['key']] = min_max_scaler.fit_transform(key)
features[['tempo']]= min_max_scaler.fit_transform(tempo)
features[['time_signature']]= min_max_scaler.fit_transform(time_signature)
features[['duration_ms']] = min_max_scaler.fit_transform(duration_ms)

# %%
features.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  \
# 0        0.0102         0.833     0.190735   0.434          0.021900
# 1        0.1990         0.743     0.314481   0.359          0.006110
# 2        0.0344         0.838     0.171624   0.412          0.000234
# 3        0.6040         0.494     0.185488   0.338          0.510000
# 4        0.1800         0.678     0.381202   0.561          0.512000
#
#         key  liveness  loudness  mode  speechiness     tempo  time_signature  \
# 0  0.181818    0.1650  0.741141     1       0.4310  0.596033            0.75
# 1  0.090909    0.1370  0.692162     1       0.0794  0.654474            0.75
# 2  0.181818    0.1590  0.791369     1       0.2890  0.158539            0.75
# 3  0.454545    0.0922  0.544709     1       0.0261  0.225162            0.75
# 4  0.454545    0.4390  0.654132     0       0.0694  0.735659            0.75
#
#    valence  target
# 0    0.286       1
# 1    0.588       1
# 2    0.173       1
# 3    0.230       1
# 4    0.904       1

# %% [markdown]
# ## Performing Feature Reduction

# %%
#Feature Reduction as with the help of this graph we can see the features having high variance
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(features)
xfeatures = range(pca.n_components_)
plt.bar(xfeatures,pca.explained_variance_)
plt.xticks(xfeatures)
plt.xlabel('PCA Features')
plt.ylabel('variance')
plt.show()

# %%
# So from above we can see five features are having high variance so we can remove the unwanted features
features=features.drop(columns=["duration_ms","energy","instrumentalness","key","mode","tempo","time_signature","valence","target"])
features.head()
# Out:
#    acousticness  danceability  liveness  loudness  speechiness
# 0        0.0102         0.833    0.1650  0.741141       0.4310
# 1        0.1990         0.743    0.1370  0.692162       0.0794
# 2        0.0344         0.838    0.1590  0.791369       0.2890
# 3        0.6040         0.494    0.0922  0.544709       0.0261
# 4        0.1800         0.678    0.4390  0.654132       0.0694

# %%
features.hist(bins=50,figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020D02CEE160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020D02D16670>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020D02D41AC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020D02D70F10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000020D02DA93A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020D02DD5850>]],
#       dtype=object)

# %% [markdown]
# # Now we will try to cluster the songs on the basis of emotion of the songs

# %%
## For clustering we will be KMeans Clustering for that first we need to know the optimum number of clusters
#import the required model
from sklearn.cluster import KMeans
#Within Cluster Sum Of Square to evaluate the efficiency of a model
wcss = []

# %% [markdown]
# ## Now we will try predicting values using different number of clusters and store the result in wcss array¶

# %%
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k,random_state=42,max_iter=300)
    km = km.fit(features)
    wcss.append(km.inertia_)

# %%
##It gives an idea of how well the objects are classified taking that number of clusters
from sklearn.metrics import silhouette_score
for n_clusters in range(2,15):
    clusterer = KMeans (n_clusters=n_clusters)
    preds = clusterer.fit_predict(features)
    centers = clusterer.cluster_centers_

    score = silhouette_score (features, preds, metric='euclidean')
    print ("For n_clusters = {}, silhouette score is {})".format(n_clusters, score))
# Out:
# For n_clusters = 2, silhouette score is 0.4824337334937478)
# For n_clusters = 3, silhouette score is 0.2883073032342218)
# For n_clusters = 4, silhouette score is 0.26262701084101425)
# For n_clusters = 5, silhouette score is 0.27004553080113314)
# For n_clusters = 6, silhouette score is 0.25917491333990894)
# For n_clusters = 7, silhouette score is 0.2558632560333833)
# For n_clusters = 8, silhouette score is 0.22123950385641863)
# For n_clusters = 9, silhouette score is 0.23200653732072782)
# For n_clusters = 10, silhouette score is 0.23305344954220716)
# For n_clusters = 11, silhouette score is 0.23232584997403724)
# For n_clusters = 12, silhouette score is 0.2289772082574839)
# For n_clusters = 13, silhouette score is 0.23276827554823307)
# For n_clusters = 14, silhouette score is 0.21263358531237195)

# %% [markdown]
# ## Plotting the wcss against number of clusters to use elbow method to determine optimal number of clusters

# %%
# Plotting the results onto a line graph, 
# `allowing us to observe 'The elbow'
plt.plot(K, wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
# Within cluster sum of squares
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ### So the optimal number of clusters seems to be 4 as elbow method was depicting 5 while silhouette_score was giving a better value with 4

# %%
## Standardize the data and fit that standardized data to KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
scaler = StandardScaler()
kmeans = KMeans(n_clusters=4)

# %%
## Made a pipeline to perform these tasks together
from sklearn.pipeline import make_pipeline
pipeline = make_pipeline(scaler,KMeans(n_clusters=4,init='k-means++',random_state=3222,max_iter=300))
pipeline.fit(features)
labels = pipeline.predict(features)
label_df = pd.DataFrame(labels)
np.shape(label_df)
features[['cluster_labels']] = label_df
features[['song_title']] = songs[['song_title']]
features[['artist']] = songs[['artist']]
features.head(10)
# Out:
#    acousticness  danceability  liveness  loudness  speechiness  \
# 0       0.01020         0.833    0.1650  0.741141       0.4310
# 1       0.19900         0.743    0.1370  0.692162       0.0794
# 2       0.03440         0.838    0.1590  0.791369       0.2890
# 3       0.60400         0.494    0.0922  0.544709       0.0261
# 4       0.18000         0.678    0.4390  0.654132       0.0694
# 5       0.00479         0.804    0.1640  0.805581       0.1850
# 6       0.01450         0.739    0.2070  0.667673       0.1560
# 7       0.02020         0.266    0.1600  0.655322       0.0371
# 8       0.04810         0.603    0.3420  0.898780       0.3470
# 9       0.00208         0.836    0.5710  0.771729       0.2370
#
#    cluster_labels         song_title            artist
# 0               3           Mask Off            Future
# 1               2            Redbone  Childish Gambino
# 2               3       Xanny Family            Future
# 3               1     Master Of None       Beach House
# 4               0     Parallel Lines       Junior Boys
# 5               3           Sneakin’             Drake
# 6               2        Childs Play             Drake
# 7               2    Gyöngyhajú lány             Omega
# 8               3  I've Seen Footage       Death Grips
# 9               0     Digital Animal       Honey Claws

# %% [markdown]
# ## Performing Dimensionality Reduction for properly visualizing the data

# %%
# PCA to reduce our data to 2 dimensions for visualisation
from sklearn.decomposition import PCA
yfeatures = features.iloc[:,0:5]
kmeans.fit(yfeatures)
y_kmeans = kmeans.predict(yfeatures)
pca = PCA(n_components=2)
principal_components = pca.fit_transform(yfeatures)

# %%
pc = pd.DataFrame(principal_components)
pc['label'] = y_kmeans
pc.columns = ['x', 'y','label']

#plot data with seaborn
cluster = sns.lmplot(data=pc, x='x', y='y', hue='label', 
                   fit_reg=False, legend=True, legend_out=True)

# %%
#Explained variance ratio will return the value for components
pca.explained_variance_ratio_
# Out:
# array([0.53393903, 0.20432391])

# %%
# Dump components relations with features:
print (pd.DataFrame(pca.components_,columns=yfeatures.columns,index = ['PC-1','PC-2']))
# Out:
#       acousticness  danceability  liveness  loudness  speechiness
# PC-1      0.944877     -0.153574 -0.095453 -0.269430    -0.043790
# PC-2     -0.036965     -0.746174  0.660915  0.065866    -0.026653

# %% [markdown]
# # Figuring out what the different clusters contain

# %%
#Counting the number of songs in each cluster
features = features.sample(frac=1)
features['cluster_labels'].value_counts()
# Out:
# 2    1197
# 0     352
# 1     242
# 3     226
# Name: cluster_labels, dtype: int64

# %%
#Analysing the first cluster
features[features['cluster_labels']==0].head(15)
# Out:
#       acousticness  danceability  liveness  loudness  speechiness  \
# 1273      0.004970         0.574     0.333  0.862946       0.0299
# 680       0.104000         0.689     0.490  0.886459       0.0978
# 1323      0.000283         0.256     0.618  0.853614       0.0964
# 1366      0.026200         0.635     0.361  0.740988       0.0581
# 636       0.004170         0.900     0.524  0.987466       0.1480
# 1783      0.019300         0.439     0.373  0.862977       0.0439
# 1903      0.185000         0.757     0.568  0.861147       0.0315
# 1414      0.045100         0.592     0.327  0.886947       0.0858
# 100       0.228000         0.630     0.487  0.859500       0.0590
# 233       0.077800         0.729     0.382  0.816072       0.0708
# 1914      0.160000         0.609     0.295  0.890180       0.0338
# 1133      0.119000         0.623     0.617  0.929826       0.0753
# 188       0.019000         0.695     0.623  0.919854       0.1270
# 1105      0.053000         0.724     0.727  0.900152       0.0392
# 581       0.011900         0.473     0.418  0.852272       0.0462
#
#       cluster_labels                song_title            artist
# 1273               0                   Beloved      Jordan Feliz
# 680                0                  The Drop        Bro Safari
# 1323               0               Zerotonin 2           Darknet
# 1366               0                     VAMOS             Oohyo
# 636                0   The Lion - Original Mix    The Partysquad
# 1783               0       In Love With a Girl      Gavin DeGraw
# 1903               0     ...Baby One More Time    Britney Spears
# 1414               0  Litty (feat. Tory Lanez)         Meek Mill
# 100                0                  Slumlord       Neon Indian
# 233                0                Sanctified         Rick Ross
# 1914               0                    Smooth           Santana
# 1133               0               Uma Thurman      Fall Out Boy
# 188                0               N.O. Bounce       Big Freedia
# 1105               0                    Lumbra  Cali Y El Dandee
# 581                0              Harlem Shake            Baauer

# %%
features[features['cluster_labels']==0].mean()
# Out:
# acousticness      0.061627
# danceability      0.544060
# liveness          0.444972
# loudness          0.850135
# speechiness       0.087751
# cluster_labels    0.000000
# dtype: float64

# %%
#Analysing the second cluster
features[features['cluster_labels']==1].head(10)
# Out:
#       acousticness  danceability  liveness  loudness  speechiness  \
# 1550       0.88600         0.386    0.1890  0.402714       0.0572
# 1856       0.96500         0.710    0.0889  0.548887       0.0534
# 1521       0.97300         0.478    0.1080  0.373590       0.0505
# 382        0.76500         0.561    0.1240  0.859835       0.0528
# 1540       0.82300         0.526    0.1140  0.610186       0.0411
# 307        0.00079         0.771    0.3410  0.374565       0.0802
# 1959       0.71900         0.836    0.0694  0.642940       0.0336
# 1895       0.21900         0.701    0.0821  0.404117       0.0938
# 64         0.37400         0.549    0.1700  0.668893       0.0633
# 1788       0.78900         0.664    0.1520  0.785026       0.0322
#
#       cluster_labels                                    song_title  \
# 1550               1                                    Angel Eyes
# 1856               1                                      Lost Boy
# 1521               1                                 For Wee Folks
# 382                1                                   Indian Food
# 1540               1                        Good Morning Heartache
# 307                1                                     Kathy Lee
# 1959               1                                       Grandad
# 1895               1  Blister in the Sun - 2002 Remastered Version
# 64                 1             Ikimiz Bir Fidaniz - Baris K Edit
# 1788               1                               Perfect Harmony
#
#                                           artist
# 1550  Tommy Flanagan, Ron Carter & Tony Williams
# 1856                                     Ruth B.
# 1521                              Joey Alexander
# 382                               Dumbo Gets Mad
# 1540                              Scott Hamilton
# 307                                  Jessy Lanza
# 1959                                  Clive Dunn
# 1895                              Violent Femmes
# 64                          Umit Aksu Orkestrasi
# 1788                                   Rags Cast

# %%
features[features['cluster_labels']==1].mean()
# Out:
# acousticness      0.762002
# danceability      0.506727
# liveness          0.151036
# loudness          0.606494
# speechiness       0.046136
# cluster_labels    1.000000
# dtype: float64

# %%
#Analysing the third cluster
features[features['cluster_labels']==2].head(10)
# Out:
#       acousticness  danceability  liveness  loudness  speechiness  \
# 282        0.08100         0.651    0.1140  0.762946       0.0274
# 1161       0.02930         0.726    0.1040  0.855566       0.1230
# 1138       0.00593         0.608    0.1210  0.893535       0.0464
# 485        0.04010         0.670    0.2930  0.851083       0.0922
# 1476       0.13100         0.522    0.1220  0.894297       0.1450
# 618        0.00749         0.587    0.2640  0.860598       0.0469
# 414        0.19500         0.605    0.2460  0.837267       0.1500
# 1669       0.03590         0.761    0.0945  0.778286       0.0539
# 96         0.06040         0.799    0.0338  0.759042       0.0396
# 1283       0.10500         0.528    0.1040  0.805581       0.0352
#
#       cluster_labels                                       song_title  \
# 282                2  Enjoy The Silence - Remastered Version Original
# 1161               2                                    Unforgettable
# 1138               2                                          Thunder
# 485                2                        In My Mind (Axwell Remix)
# 1476               2                                             Open
# 618                2                                 Oh My - Club Mix
# 414                2                                          Obedear
# 1669               2                             You Make Me Wanna...
# 96                 2               The Magnificent Seven - Remastered
# 1283               2                                King Of The World
#
#                                         artist
# 282                               Depeche Mode
# 1161                            French Montana
# 1138                           Imagine Dragons
# 485   Ivan Gough & Feenixpawl feat. Georgi Kay
# 1476                               Yellow Claw
# 618                             The Partysquad
# 414                                Purity Ring
# 1669                                     Usher
# 96                                   The Clash
# 1283                             Natalie Grant

# %%
features[features['cluster_labels']==2].mean()
# Out:
# acousticness      0.111257
# danceability      0.649070
# liveness          0.126446
# loudness          0.813370
# speechiness       0.063935
# cluster_labels    2.000000
# dtype: float64

# %%
#Analysing the third cluster
features[features['cluster_labels']==3].head(10)
# Out:
#       acousticness  danceability  liveness  loudness  speechiness  \
# 1942       0.00733         0.845    0.0575  0.843214        0.188
# 556        0.08290         0.722    0.0533  0.755505        0.352
# 792        0.36000         0.784    0.1150  0.798780        0.292
# 1187       0.06560         0.828    0.1220  0.713053        0.199
# 1611       0.28200         0.369    0.2660  0.847667        0.384
# 1967       0.00141         0.895    0.2740  0.737359        0.216
# 259        0.01930         0.413    0.1000  0.776395        0.241
# 582        0.00207         0.931    0.0920  0.754224        0.269
# 816        0.17200         0.683    0.3570  0.849558        0.353
# 1437       0.58800         0.614    0.1050  0.901769        0.352
#
#       cluster_labels                                  song_title  \
# 1942               3  Jenny from the Block - Track Masters Remix
# 556                3          Females Welcomed (feat. Reija Lee)
# 792                3                                     Tuesday
# 1187               3                                    Lollipop
# 1611               3                                       Close
# 1967               3                                Hoochie Mama
# 259                3                                        Pony
# 582                3                                   Purp Walk
# 816                3                                  Holding On
# 1437               3                                    Save You
#
#               artist
# 1942  Jennifer Lopez
# 556   Trinidad James
# 792    ILoveMakonnen
# 1187       Lil Wayne
# 1611         IZECOLD
# 1967     2 LIVE CREW
# 259    Pretty Sister
# 582           Lunice
# 816       Disclosure
# 1437       Wahlstedt

# %%
features[features['cluster_labels']==3].mean()
# Out:
# acousticness      0.172998
# danceability      0.691518
# liveness          0.178742
# loudness          0.798253
# speechiness       0.302301
# cluster_labels    3.000000
# dtype: float64

# %%
## On analysing the mean feature values of the clusters following mood can be assigned to a song belonging to the particular clusterfeatures[features['cluster_labels']==0]:
mapping={0 : "Feeling energetic",1 : "Feeling Happy", 2:"Feeling passionate",3: "Feeling Calm"}
features['cluster_labels'] = [mapping[i] for i in features['cluster_labels']]
features.tail()
# Out:
#       acousticness  danceability  liveness  loudness  speechiness  \
# 112        0.65600         0.780    0.1290  0.696737       0.0329
# 698        0.00525         0.700    0.6570  0.815340       0.1490
# 1104       0.20400         0.685    0.0722  0.853248       0.0930
# 951        0.10900         0.748    0.1500  0.854437       0.0285
# 1648       0.00354         0.568    0.4780  0.900915       0.0450
#
#           cluster_labels                   song_title           artist
# 112        Feeling Happy           Please Mr. Postman  The Marvelettes
# 698    Feeling energetic  No New Friends - SFTB Remix        DJ Khaled
# 1104  Feeling passionate                 Si Tú La Ves        Nicky Jam
# 951   Feeling passionate                        Bambi          Jidenna
# 1648   Feeling energetic        Starlight - Radio Mix             SOVI

# %% [markdown]
# ## Yeah the model successfully clustered the songs in different mood groups

# %% [markdown]
# ### Lets begin classifying the song the person is listening to, to these mood groups so that can come to know the mood of the person based on the somg

# %%
## We will try classifiying the songs using different classifiers and then using ensemble learning will try to vote and use the maximum accuracy
#Start by importing the required libraries

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.multiclass import unique_labels

# %%
## Detecting the features and the labels
X = features.iloc[:,[0,1,2,3,4]]
y = features.iloc[:,5]
X.head()
# Out:
#       acousticness  danceability  liveness  loudness  speechiness
# 282        0.08100         0.651     0.114  0.762946       0.0274
# 1161       0.02930         0.726     0.104  0.855566       0.1230
# 1138       0.00593         0.608     0.121  0.893535       0.0464
# 485        0.04010         0.670     0.293  0.851083       0.0922
# 1476       0.13100         0.522     0.122  0.894297       0.1450

# %%
y.head()
# Out:
# 282     Feeling passionate
# 1161    Feeling passionate
# 1138    Feeling passionate
# 485     Feeling passionate
# 1476    Feeling passionate
# Name: cluster_labels, dtype: object

# %% [markdown]
# ## Splitting the training and text set

# %%
#Performed splitting having 30% test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1)

# %% [markdown]
# # We will try classifying the song to the mood using different classifiers and will even use different ensemble learning methods like voting classifier,bagging,boosting,random forest and will see which is giving the most accurate result

# %% [markdown]
# ## Ensemble Learning (Voting Classifier)

# %%
## Classification using Voting Classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score

# %%
##Instantiate the classifier
dt = DecisionTreeClassifier(max_depth=2,random_state=1)
lr = LogisticRegression(random_state=1)
knn = KNeighborsClassifier()

# %%
##Fitting the model to training data and comparing the accuracy of the classifiers
Classifiers = {'LogisticRegression':lr,'KNearestNeighbors':knn,'DecisionTreeClassifier':dt}
for clf_name,clf in Classifiers.items():
  clf.fit(X_train,y_train)
  y_pred = clf.predict(X_test)
  print('{:s}:{:.3f}'.format(clf_name,accuracy_score(y_test,y_pred)))
# Out:
# LogisticRegression:0.927
# KNearestNeighbors:0.942
# DecisionTreeClassifier:0.842

# %%
X_test.head()
# Out:
#       acousticness  danceability  liveness  loudness  speechiness
# 1934        0.2650         0.793    0.2070  0.861116       0.0405
# 1954        0.4220         0.927    0.0422  0.626289       0.0908
# 761         0.8580         0.741    0.1330  0.807441       0.0583
# 1876        0.9940         0.206    0.1310  0.236231       0.0431
# 1168        0.0905         0.648    0.0831  0.808173       0.0746

# %%
##Using Voting Classifier
vc = VotingClassifier(estimators = Classifiers.items())
vc.fit(X_train,y_train)
y_pred = vc.predict(X_test)
print('Voting Classifier:{:.3f}'.format(accuracy_score(y_test,y_pred)))
# Out:
# Voting Classifier:0.942

# %%
##Evaluating Accuracy Using Confusion Matrix And Classification Report
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 52   0   1   6]
#  [  0  55   1  11]
#  [  0   0  89  10]
#  [  0   2   4 375]]
#                     precision    recall  f1-score   support
#
#       Feeling Calm       1.00      0.88      0.94        59
#      Feeling Happy       0.96      0.82      0.89        67
#  Feeling energetic       0.94      0.90      0.92        99
# Feeling passionate       0.93      0.98      0.96       381
#
#           accuracy                           0.94       606
#          macro avg       0.96      0.90      0.92       606
#       weighted avg       0.94      0.94      0.94       606

# %% [markdown]
# ## Bagging Classifier

# %%
##It trains different models using the same algorithm for different parts of the training set 
from sklearn.ensemble import BaggingClassifier
seed=1
knn = KNeighborsClassifier()
bc = BaggingClassifier(base_estimator=knn,n_estimators=300,n_jobs=-1,random_state=3222)

# %%
##Fitting data to train and test and predicting
bc.fit(X_train,y_train)
y_pred = bc.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.9488448844884488

# %%
##Evaluating Accuracy Using Confusion Matrix And Classification Report
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 49   1   0   9]
#  [  0  61   1   5]
#  [  0   0  92   7]
#  [  0   1   7 373]]
#                     precision    recall  f1-score   support
#
#       Feeling Calm       1.00      0.83      0.91        59
#      Feeling Happy       0.97      0.91      0.94        67
#  Feeling energetic       0.92      0.93      0.92        99
# Feeling passionate       0.95      0.98      0.96       381
#
#           accuracy                           0.95       606
#          macro avg       0.96      0.91      0.93       606
#       weighted avg       0.95      0.95      0.95       606

# %% [markdown]
# ## Random Forest Classifier

# %%
#Instantiating the model
##Basically Random Forest is an ensemble method where the base estimator is the decision tree
rf = RandomForestClassifier(n_estimators=300,min_samples_leaf=0.12,random_state=1)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.8250825082508251

# %%
##Evaluating the model
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[  1   1  13  44]
#  [  0  46   5  16]
#  [  0   0  93   6]
#  [  0   8  13 360]]
#                     precision    recall  f1-score   support
#
#       Feeling Calm       1.00      0.02      0.03        59
#      Feeling Happy       0.84      0.69      0.75        67
#  Feeling energetic       0.75      0.94      0.83        99
# Feeling passionate       0.85      0.94      0.89       381
#
#           accuracy                           0.83       606
#          macro avg       0.86      0.65      0.63       606
#       weighted avg       0.84      0.83      0.78       606

# %% [markdown]
# ## Fetching features by giving song title using spotify api

# %%
import spotipy
import spotipy.util as util
import requests

def get_id(track_name: str, token: str) -> str:
    headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + token,
    }
    params = [
    ('q', track_name),
    ('type', 'track'),
    ]
    try:
        response = requests.get('https://api.spotify.com/v1/search', 
                    headers = headers, params = params, timeout = 5)
        json = response.json()
        first_result = json['tracks']['items'][0]
        track_id = first_result['id']
        return track_id
    except:
        return None

def get_features(track_id: str, token: str) -> dict:
    sp = spotipy.Spotify(auth=token)
    try:
        features = sp.audio_features([track_id])
        return features[0]
    except:
        return None

username = 'Enter Username'
client_id ='Enter Your Client ID'
client_secret = 'Enter Your Client Secret'
redirect_uri = 'http://localhost:7777/callback'
scope = 'user-read-recently-played'

token = util.prompt_for_user_token(username=username, scope=scope, client_id=client_id,client_secret=client_secret,redirect_uri=redirect_uri)
#print(token)

# %% [markdown]
# ## Asking the User to give Song Title using Speech or Text

# %%
k = input("If you want to use Speech type 'S' or if you want to enter the song name manually type 'T': ")
if(k == 'S'):
    r = sr.Recognizer()
    with sr.Microphone(device_index=1) as source:
        r.adjust_for_ambient_noise(source,duration=1)
        print("Say the Song name: ")
        audio = r.listen(source)
        print("Ok")
    try:
        title = r.recognize_google(audio)
        print("Text: "+ title)
    except:
        print("Cannot Understand try typing the name of the song: ")
        title = input("enter song name: ")
elif(k == 'T'):
    title = input("enter song name: ")
else:
    print("Type 'S' or 'T' in your next run ")
# Out:
# If you want to use Speech type 'S' or if you want to enter the song name manually type 'T': S
# Say the Song name:
# Ok
# Text: memories

# %%
spotify_id = get_id(title, token)
#print(lucy_id)
song_features = get_features(spotify_id, token)
print(song_features)
# Out:
# {'danceability': 0.764, 'energy': 0.32, 'key': 11, 'loudness': -7.209, 'mode': 1, 'speechiness': 0.0546, 'acousticness': 0.837, 'instrumentalness': 0, 'liveness': 0.0822, 'valence': 0.575, 'tempo': 91.019, 'type': 'audio_features', 'id': '2b8fOow8UzyDFAE27YhOZM', 'uri': 'spotify:track:2b8fOow8UzyDFAE27YhOZM', 'track_href': 'https://api.spotify.com/v1/tracks/2b8fOow8UzyDFAE27YhOZM', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2b8fOow8UzyDFAE27YhOZM', 'duration_ms': 189486, 'time_signature': 4}

# %%
res = {key: song_features[key] for key in song_features.keys() 
                               & {'acousticness','danceability','liveness','loudness','speechiness'}}
k={}
for i in res.keys():
    k[i]=[res[i]]
df=pd.DataFrame(k)    
df
# Out:
#    acousticness  danceability  liveness  speechiness  loudness
# 0         0.837         0.764    0.0822       0.0546    -7.209

# %% [markdown]
# ## Since bagging classifier was most accurate we are using it to predict the accuracy

# %%
y_ans = bc.predict(df)
print('It seems like you are {:s}'.format(y_ans[0]))
# Out:
# It seems like you are Feeling Happy

# %%
y_ans_songs = pd.DataFrame(features[features['cluster_labels']==y_ans[0]].song_title)
print('Here is a list of some more songs you may like')
y_ans_songs.head()
# Out:
# Here is a list of some more songs you may like
#                   song_title
# 1550              Angel Eyes
# 1856                Lost Boy
# 1521           For Wee Folks
# 382              Indian Food
# 1540  Good Morning Heartache
